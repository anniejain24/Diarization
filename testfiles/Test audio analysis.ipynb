# %% [markdown]
# Convert mp4 to mp3: DON'T HAVE TO RUN EVERY TIME

# %%
# testing whether push from local works
import moviepy

# %%
from moviepy.editor import *

# %%
import os
os.getcwd()
# Out:
# '/endosome/work/bioinformatics/s229618'

# %% [markdown]
# Trying some test audio analysis using librosa

# %%
#pip install librosa
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting librosa
#   Downloading librosa-0.10.1-py3-none-any.whl (253 kB)
#      |████████████████████████████████| 253 kB 5.4 MB/s eta 0:00:01
# Collecting numpy!=1.22.0,!=1.22.1,!=1.22.2,>=1.20.3
#   Downloading numpy-1.24.4-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (17.3 MB)
#      |████████████████████████████████| 17.3 MB 55.2 MB/s eta 0:00:01
# Collecting typing-extensions>=4.1.1
#   Downloading typing_extensions-4.9.0-py3-none-any.whl (32 kB)
# Requirement already satisfied: numba>=0.51.0 in /cm/shared/apps/python/3.8.x-anaconda/lib/python3.8/site-packages (from librosa) (0.53.1)
# Collecting audioread>=2.1.9
#   Downloading audioread-3.0.1-py3-none-any.whl (23 kB)
# Requirement already satisfied: scikit-learn>=0.20.0 in /cm/shared/apps/python/3.8.x-anaconda/lib/python3.8/site-packages (from librosa) (0.24.1)
# Collecting soundfile>=0.12.1
#   Downloading soundfile-0.12.1-py2.py3-none-manylinux_2_17_x86_64.whl (1.3 MB)
#      |████████████████████████████████| 1.3 MB 76.5 MB/s eta 0:00:01
# Collecting pooch>=1.0
#   Downloading pooch-1.8.0-py3-none-any.whl (62 kB)
#      |████████████████████████████████| 62 kB 1.0 MB/s  eta 0:00:01
# Requirement already satisfied: decorator>=4.3.0 in /home2/s229618/.local/lib/python3.8/site-packages (from librosa) (4.4.2)
# Requirement already satisfied: scipy>=1.2.0 in /cm/shared/apps/python/3.8.x-anaconda/lib/python3.8/site-packages (from librosa) (1.6.2)
# Requirement already satisfied: joblib>=0.14 in /cm/shared/apps/python/3.8.x-anaconda/lib/python3.8/site-packages (from librosa) (1.0.1)
# Collecting soxr>=0.3.2
#   Downloading soxr-0.3.7-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      |████████████████████████████████| 1.3 MB 82.8 MB/s eta 0:00:01
# Requirement already satisfied: msgpack>=1.0 in /cm/shared/apps/python/3.8.x-anaconda/lib/python3.8/site-packages (from librosa) (1.0.2)
# Collecting lazy-loader>=0.1
#   Downloading lazy_loader-0.3-py3-none-any.whl (9.1 kB)
# Requirement already satisfied: llvmlite<0.37,>=0.36.0rc1 in /cm/shared/apps/python/3.8.x-anaconda/lib/python3.8/site-packages (from numba>=0.51.0->librosa) (0.36.0)
# Requirement already satisfied: setuptools in /cm/shared/apps/python/3.8.x-anaconda/lib/python3.8/site-packages (from numba>=0.51.0->librosa) (52.0.0.post20210125)
# Requirement already satisfied: requests>=2.19.0 in /cm/shared/apps/python/3.8.x-anaconda/lib/python3.8/site-packages (from pooch>=1.0->librosa) (2.25.1)
# Requirement already satisfied: packaging>=20.0 in /cm/shared/apps/python/3.8.x-anaconda/lib/python3.8/site-packages (from pooch>=1.0->librosa) (20.9)
# Collecting platformdirs>=2.5.0
#   Downloading platformdirs-4.2.0-py3-none-any.whl (17 kB)
# Requirement already satisfied: pyparsing>=2.0.2 in /cm/shared/apps/python/3.8.x-anaconda/lib/python3.8/site-packages (from packaging>=20.0->pooch>=1.0->librosa) (2.4.7)
# Requirement already satisfied: chardet<5,>=3.0.2 in /cm/shared/apps/python/3.8.x-anaconda/lib/python3.8/site-packages (from requests>=2.19.0->pooch>=1.0->librosa) (4.0.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /cm/shared/apps/python/3.8.x-anaconda/lib/python3.8/site-packages (from requests>=2.19.0->pooch>=1.0->librosa) (1.26.4)
# Requirement already satisfied: idna<3,>=2.5 in /cm/shared/apps/python/3.8.x-anaconda/lib/python3.8/site-packages (from requests>=2.19.0->pooch>=1.0->librosa) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /cm/shared/apps/python/3.8.x-anaconda/lib/python3.8/site-packages (from requests>=2.19.0->pooch>=1.0->librosa) (2020.12.5)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /cm/shared/apps/python/3.8.x-anaconda/lib/python3.8/site-packages (from scikit-learn>=0.20.0->librosa) (2.1.0)
# Collecting numpy!=1.22.0,!=1.22.1,!=1.22.2,>=1.20.3
#   Downloading numpy-1.22.4-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (16.9 MB)
#      |████████████████████████████████| 16.9 MB 76.1 MB/s eta 0:00:01    |███████████████▋                | 8.2 MB 76.1 MB/s eta 0:00:01
# Requirement already satisfied: cffi>=1.0 in /cm/shared/apps/python/3.8.x-anaconda/lib/python3.8/site-packages (from soundfile>=0.12.1->librosa) (1.14.5)
# Requirement already satisfied: pycparser in /cm/shared/apps/python/3.8.x-anaconda/lib/python3.8/site-packages (from cffi>=1.0->soundfile>=0.12.1->librosa) (2.20)
# Installing collected packages: numpy, platformdirs, typing-extensions, soxr, soundfile, pooch, lazy-loader, audioread, librosa
#   WARNING: The scripts f2py, f2py3 and f2py3.8 are installed in '/home2/s229618/.local/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
# Successfully installed audioread-3.0.1 lazy-loader-0.3 librosa-0.10.1 numpy-1.22.4 platformdirs-4.2.0 pooch-1.8.0 soundfile-0.12.1 soxr-0.3.7 typing-extensions-4.9.0
# Note: you may need to restart the kernel to use updated packages.

# %%
# https://www.topcoder.com/thrive/articles/audio-data-analysis-using-python
import librosa
import matplotlib.pyplot as plt
audio = '/archive/shared/sim_center/shared/ameer/COSCE/audio/01_cough_1/01_0001_144726.wav'
x, sr = librosa.load(audio)
X = librosa.stft(x)
Xdb = librosa.amplitude_to_db(abs(X))
plt.figure(figsize = (10, 5))
librosa.display.specshow(Xdb, sr = sr, x_axis = 'time', y_axis = 'hz')
plt.colorbar()

# %%
# https://www.topcoder.com/thrive/articles/audio-data-analysis-using-python
plt.figure(figsize = (10, 5))
librosa.display.specshow(Xdb, sr = sr, x_axis = 'time', y_axis = 'hz')
plt.xlim(0, 100)
plt.colorbar()

# %%
import sklearn
from sklearn import preprocessing
spectral_centroids = librosa.feature.spectral_centroid(y=x, sr = sr)[0]
#spectral_centroids.shape(775, )

# Computing the time variable for visualization

plt.figure(figsize = (12, 4))
frames = range(len(spectral_centroids))
t = librosa.frames_to_time(frames)

# Normalising the spectral centroid for visualisation

def normalize(x, axis = 0):
  return preprocessing.minmax_scale(x, axis = axis)

#Plotting the Spectral Centroid along the waveform
librosa.display.waveshow(x, sr = sr, alpha = 0.4)
plt.plot(t, normalize(spectral_centroids), color = 'b')

# %%
librosa.display.waveshow(x, sr = sr, alpha = 0.4)
plt.plot(t, normalize(spectral_centroids), color = 'b')
plt.xlim(0, 100)
plt.ylim(-0.4, 0.6)
# Out:
# (-0.4, 0.6)

# %%
spectral_rolloff = librosa.feature.spectral_rolloff(y=x + 0.01, sr = sr)[0]
plt.figure(figsize = (12, 4))
librosa.display.waveshow(x, sr = sr, alpha = 0.4)
plt.plot(t, normalize(spectral_rolloff), color = 'r')

# %%
spectral_bandwidth_2 = librosa.feature.spectral_bandwidth(y=x + 0.01, sr = sr)[0]
spectral_bandwidth_3 = librosa.feature.spectral_bandwidth(y=x + 0.01, sr = sr, p = 3)[0]
spectral_bandwidth_4 = librosa.feature.spectral_bandwidth(y=x + 0.01, sr = sr, p = 4)[0]
plt.figure(figsize = (15, 9))
librosa.display.waveshow(x, sr = sr, alpha = 0.4)
plt.plot(t, normalize(spectral_bandwidth_2), color = 'r')
plt.plot(t, normalize(spectral_bandwidth_3), color = 'g')
plt.plot(t, normalize(spectral_bandwidth_4), color = 'y')

# %% [markdown]
# Trying some signal processing stuff

# %% [markdown]
# Trying Fundamental Frequency

# %%
f0, voiced_flag, voiced_probs = librosa.pyin(y=x, sr=sr, fmin=65, fmax=2093)

# %%
times = librosa.times_like(f0)

# %%
# overlay over a spectrogram
import numpy as np
D = librosa.amplitude_to_db(np.abs(librosa.stft(x)), ref=np.max)
fig, ax = plt.subplots()
img = librosa.display.specshow(D, x_axis='time', y_axis='log', ax=ax)
ax.set(title='pYIN fundamental frequency estimation')
fig.colorbar(img, ax=ax, format="%+2.f dB")
ax.plot(times, f0, label='f0', color='cyan', linewidth=3)
ax.legend(loc='upper right')

# %%
fig, ax = plt.subplots()
img = librosa.display.specshow(D, x_axis='time', y_axis='log', ax=ax)
ax.set(title='pYIN fundamental frequency estimation')
fig.colorbar(img, ax=ax, format="%+2.f dB")
ax.plot(times, f0, label='f0', color='cyan', linewidth=3)
ax.legend(loc='upper right')
plt.xlim(0, 100)
# Out:
# (0.0, 100.0)

# %%
np.nanmean(f0)
# Out:
# 104.0547502765093

# %% [markdown]
# Try stuff on second video (DON'T NEED TO RUN THIS AGAIN)

# %%
audio2 = '/archive/shared/sim_center/shared/ameer/COSCE/audio/01_cough_1/01_0002_144727.wav'
x2, sr2 = librosa.load(audio2)
X2 = librosa.stft(x2)
Xdb2 = librosa.amplitude_to_db(abs(X2))
plt.figure(figsize = (10, 5))
librosa.display.specshow(Xdb2, sr = sr2, x_axis = 'time', y_axis = 'hz')
plt.colorbar()

# %%
f02, voiced_flag2, voiced_probs2 = librosa.pyin(y=x2, sr=sr2, fmin=65, fmax=2093)
times2 = librosa.times_like(f02)
D2 = librosa.amplitude_to_db(np.abs(librosa.stft(x2)), ref=np.max)
fig, ax = plt.subplots()
img = librosa.display.specshow(D2, x_axis='time', y_axis='log', ax=ax)
ax.set(title='pYIN fundamental frequency estimation')
fig.colorbar(img, ax=ax, format="%+2.f dB")
ax.plot(times2, f02, label='f0', color='cyan', linewidth=3)
ax.legend(loc='upper right')

# %%
np.nanmean(f02)
# Out:
# 273.7535481427363
